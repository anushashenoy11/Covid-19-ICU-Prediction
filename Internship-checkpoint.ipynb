# %%
import pandas as pd
import numpy as np
df=pd.read_excel(r'C:\Users\Ashish\Desktop\imp_features.xlsx')
df.head()
# Out:
#    LACTATE_MEAN  RESPIRATORY_RATE_DIFF_REL  BLOODPRESSURE_SISTOLIC_DIFF_REL  \
# 0           NaN                  -1.000000                        -1.000000
# 1           NaN                  -1.000000                        -1.000000
# 2      1.000000                        NaN                              NaN
# 3           NaN                        NaN                              NaN
# 4     -0.963023                   0.096774                         0.407558
#
#    HEART_RATE_DIFF  BLOODPRESSURE_DIASTOLIC_DIFF_REL  TEMPERATURE_DIFF_REL  \
# 0        -1.000000                         -1.000000             -1.000000
# 1        -1.000000                         -1.000000             -1.000000
# 2              NaN                               NaN                   NaN
# 3              NaN                               NaN             -1.000000
# 4         0.114504                         -0.389967             -0.242282
#
#    OXYGEN_SATURATION_DIFF_REL  HEMOGLOBIN_MEAN  HTN  HEMATOCRITE_MEAN  ...  \
# 0                   -1.000000              NaN  0.0               NaN  ...
# 1                   -1.000000              NaN  0.0               NaN  ...
# 2                         NaN         0.109756  0.0          0.090147  ...
# 3                   -1.000000              NaN  0.0               NaN  ...
# 4                   -0.814433        -0.353659  0.0         -0.320755  ...
#
#    SAT02_ARTERIAL_MEAN  DISEASE GROUPING 1  TTPA_MEAN  GGT_MEAN  \
# 0                  NaN                 0.0        NaN       NaN
# 1                  NaN                 0.0        NaN       NaN
# 2             0.939394                 0.0  -0.825613 -0.945093
# 3                  NaN                 0.0        NaN       NaN
# 4             0.848485                 0.0  -0.846633 -0.669393
#
#    DISEASE GROUPING 2  SODIUM_MEAN  PH_VENOUS_MEAN  FFA_MEAN  CREATININ_MEAN  \
# 0                 0.0          NaN             NaN       NaN             NaN
# 1                 0.0          NaN             NaN       NaN             NaN
# 2                 0.0    -0.028571        0.363636 -0.742004       -0.868365
# 3                 0.0          NaN             NaN       NaN             NaN
# 4                 0.0     0.142857        0.393939 -0.859275       -0.926398
#
#    ICU
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
#
# [5 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# LACTATE_MEAN                        1104
# RESPIRATORY_RATE_DIFF_REL            748
# BLOODPRESSURE_SISTOLIC_DIFF_REL      685
# HEART_RATE_DIFF                      685
# BLOODPRESSURE_DIASTOLIC_DIFF_REL     685
# TEMPERATURE_DIFF_REL                 694
# OXYGEN_SATURATION_DIFF_REL           686
# HEMOGLOBIN_MEAN                     1104
# HTN                                    5
# HEMATOCRITE_MEAN                    1104
# ALBUMIN_MEAN                        1104
# PLATELETS_MEAN                      1104
# BE_VENOUS_MEAN                      1104
# BE_ARTERIAL_MEAN                    1104
# LEUKOCYTES_MEAN                     1104
# UREA_MEAN                           1104
# NEUTROPHILES_MEAN                   1104
# POTASSIUM_MEAN                      1104
# DISEASE GROUPING 5                     5
# SAT02_VENOUS_MEAN                   1104
# P02_VENOUS_MEAN                     1104
# DISEASE GROUPING 3                     5
# SAT02_ARTERIAL_MEAN                 1104
# DISEASE GROUPING 1                     5
# TTPA_MEAN                           1104
# GGT_MEAN                            1104
# DISEASE GROUPING 2                     5
# SODIUM_MEAN                         1104
# PH_VENOUS_MEAN                      1104
# FFA_MEAN                            1104
# CREATININ_MEAN                      1104
# ICU                                    0
# dtype: int64

# %%
df.fillna(method='bfill',inplace=True)
df
# Out:
#       LACTATE_MEAN  RESPIRATORY_RATE_DIFF_REL  \
# 0         1.000000                  -1.000000
# 1         1.000000                  -1.000000
# 2         1.000000                   0.096774
# 3        -0.963023                   0.096774
# 4        -0.963023                   0.096774
# ...            ...                        ...
# 1920     -0.897773                  -1.000000
# 1921     -0.897773                  -1.000000
# 1922      1.000000                  -1.000000
# 1923      1.000000                  -1.000000
# 1924      1.000000                  -0.612903
#
#       BLOODPRESSURE_SISTOLIC_DIFF_REL  HEART_RATE_DIFF  \
# 0                           -1.000000        -1.000000
# 1                           -1.000000        -1.000000
# 2                            0.407558         0.114504
# 3                            0.407558         0.114504
# 4                            0.407558         0.114504
# ...                               ...              ...
# 1920                        -1.000000        -1.000000
# 1921                        -1.000000        -1.000000
# 1922                        -1.000000        -1.000000
# 1923                        -1.000000        -1.000000
# 1924                        -0.585967        -0.633588
#
#       BLOODPRESSURE_DIASTOLIC_DIFF_REL  TEMPERATURE_DIFF_REL  \
# 0                            -1.000000             -1.000000
# 1                            -1.000000             -1.000000
# 2                            -0.389967             -1.000000
# 3                            -0.389967             -1.000000
# 4                            -0.389967             -0.242282
# ...                                ...                   ...
# 1920                         -1.000000             -1.000000
# 1921                         -1.000000             -1.000000
# 1922                         -1.000000             -1.000000
# 1923                         -1.000000             -1.000000
# 1924                         -0.701863             -0.551337
#
#       OXYGEN_SATURATION_DIFF_REL  HEMOGLOBIN_MEAN  HTN  HEMATOCRITE_MEAN  ...  \
# 0                      -1.000000         0.109756  0.0          0.090147  ...
# 1                      -1.000000         0.109756  0.0          0.090147  ...
# 2                      -1.000000         0.109756  0.0          0.090147  ...
# 3                      -1.000000        -0.353659  0.0         -0.320755  ...
# 4                      -0.814433        -0.353659  0.0         -0.320755  ...
# ...                          ...              ...  ...               ...  ...
# 1920                   -1.000000        -0.158537  0.0         -0.064990  ...
# 1921                   -1.000000        -0.158537  0.0         -0.064990  ...
# 1922                   -1.000000        -0.292683  0.0         -0.157233  ...
# 1923                   -1.000000        -0.292683  0.0         -0.157233  ...
# 1924                   -0.835052        -0.292683  0.0         -0.157233  ...
#
#       SAT02_ARTERIAL_MEAN  DISEASE GROUPING 1  TTPA_MEAN  GGT_MEAN  \
# 0                0.939394                 0.0  -0.825613 -0.945093
# 1                0.939394                 0.0  -0.825613 -0.945093
# 2                0.939394                 0.0  -0.825613 -0.945093
# 3                0.848485                 0.0  -0.846633 -0.669393
# 4                0.848485                 0.0  -0.846633 -0.669393
# ...                   ...                 ...        ...       ...
# 1920             0.939394                 0.0  -0.869210 -0.960280
# 1921             0.939394                 0.0  -0.869210 -0.960280
# 1922             0.939394                 0.0  -0.846633 -0.962617
# 1923             0.939394                 0.0  -0.846633 -0.962617
# 1924             0.939394                 0.0  -0.846633 -0.962617
#
#       DISEASE GROUPING 2  SODIUM_MEAN  PH_VENOUS_MEAN  FFA_MEAN  \
# 0                    0.0    -0.028571        0.363636 -0.742004
# 1                    0.0    -0.028571        0.363636 -0.742004
# 2                    0.0    -0.028571        0.363636 -0.742004
# 3                    0.0     0.142857        0.393939 -0.859275
# 4                    0.0     0.142857        0.393939 -0.859275
# ...                  ...          ...             ...       ...
# 1920                 0.0    -0.085714        0.424242 -0.782516
# 1921                 0.0    -0.085714        0.424242 -0.782516
# 1922                 0.0     0.200000        0.363636 -0.825160
# 1923                 0.0     0.200000        0.363636 -0.825160
# 1924                 0.0     0.200000        0.363636 -0.825160
#
#       CREATININ_MEAN  ICU
# 0          -0.868365    0
# 1          -0.868365    0
# 2          -0.868365    0
# 3          -0.926398    0
# 4          -0.926398    1
# ...              ...  ...
# 1920       -0.934890    0
# 1921       -0.934890    0
# 1922       -0.944798    0
# 1923       -0.944798    0
# 1924       -0.944798    0
#
# [1925 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# LACTATE_MEAN                        0
# RESPIRATORY_RATE_DIFF_REL           0
# BLOODPRESSURE_SISTOLIC_DIFF_REL     0
# HEART_RATE_DIFF                     0
# BLOODPRESSURE_DIASTOLIC_DIFF_REL    0
# TEMPERATURE_DIFF_REL                0
# OXYGEN_SATURATION_DIFF_REL          0
# HEMOGLOBIN_MEAN                     0
# HTN                                 0
# HEMATOCRITE_MEAN                    0
# ALBUMIN_MEAN                        0
# PLATELETS_MEAN                      0
# BE_VENOUS_MEAN                      0
# BE_ARTERIAL_MEAN                    0
# LEUKOCYTES_MEAN                     0
# UREA_MEAN                           0
# NEUTROPHILES_MEAN                   0
# POTASSIUM_MEAN                      0
# DISEASE GROUPING 5                  0
# SAT02_VENOUS_MEAN                   0
# P02_VENOUS_MEAN                     0
# DISEASE GROUPING 3                  0
# SAT02_ARTERIAL_MEAN                 0
# DISEASE GROUPING 1                  0
# TTPA_MEAN                           0
# GGT_MEAN                            0
# DISEASE GROUPING 2                  0
# SODIUM_MEAN                         0
# PH_VENOUS_MEAN                      0
# FFA_MEAN                            0
# CREATININ_MEAN                      0
# ICU                                 0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,31].values

# %%
from sklearn.preprocessing import LabelEncoder
l_x=LabelEncoder()
x[:,1]=l_x.fit_transform(x[:,1])
x[:,2]=l_x.fit_transform(x[:,2])
x[:,3]=l_x.fit_transform(x[:,3])
x[:,4]=l_x.fit_transform(x[:,4])
x[:,5]=l_x.fit_transform(x[:,5])
x[:,6]=l_x.fit_transform(x[:,6])
x[:,7]=l_x.fit_transform(x[:,7])
x[:,8]=l_x.fit_transform(x[:,8])
x[:,9]=l_x.fit_transform(x[:,9])
x[:,10]=l_x.fit_transform(x[:,10])
x[:,11]=l_x.fit_transform(x[:,11])
x[:,12]=l_x.fit_transform(x[:,12])
x[:,13]=l_x.fit_transform(x[:,13])
x[:,14]=l_x.fit_transform(x[:,14])
x[:,15]=l_x.fit_transform(x[:,15])
x[:,16]=l_x.fit_transform(x[:,16])
x[:,26]=l_x.fit_transform(x[:,17])
x[:,18]=l_x.fit_transform(x[:,18])
x[:,26]=l_x.fit_transform(x[:,19])
x[:,26]=l_x.fit_transform(x[:,20])
x[:,26]=l_x.fit_transform(x[:,21])
x[:,22]=l_x.fit_transform(x[:,22])
x[:,26]=l_x.fit_transform(x[:,23])
x[:,24]=l_x.fit_transform(x[:,24])
x[:,26]=l_x.fit_transform(x[:,25])
x[:,26]=l_x.fit_transform(x[:,26])
x[:,26]=l_x.fit_transform(x[:,27])
x[:,26]=l_x.fit_transform(x[:,28])
x[:,26]=l_x.fit_transform(x[:,29])
x[:,26]=l_x.fit_transform(x[:,30])
x
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          3.63636364e-01, -7.42004264e-01, -8.68365180e-01],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          3.63636364e-01, -7.42004264e-01, -8.68365180e-01],
#        [ 1.00000000e+00,  1.40000000e+02,  4.63000000e+02, ...,
#          3.63636364e-01, -7.42004264e-01, -8.68365180e-01],
#        ...,
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          3.63636364e-01, -8.25159915e-01, -9.44798301e-01],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          3.63636364e-01, -8.25159915e-01, -9.44798301e-01],
#        [ 1.00000000e+00,  7.70000000e+01,  2.07000000e+02, ...,
#          3.63636364e-01, -8.25159915e-01, -9.44798301e-01]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
y_train
# Out:
# array([1, 1, 1, ..., 1, 0, 1], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.fit_transform(x_test)
x_test
# Out:
# array([[ 0.7993602 , -0.63078332,  0.33105826, ..., -0.06619302,
#         -0.09419673,  0.14392131],
#        [ 0.7993602 , -0.63078332, -0.67711584, ..., -0.06619302,
#         -0.09419673, -0.14039189],
#        [-1.26065219, -0.63078332, -0.67711584, ...,  0.44428757,
#         -0.09419673, -0.10279675],
#        ...,
#        [ 0.7993602 ,  1.01319827, -0.67711584, ...,  0.69952787,
#         -0.69532446, -0.46464991],
#        [ 0.7993602 , -0.63078332, -0.67711584, ..., -0.83191392,
#         -0.09419673, -0.36596269],
#        [ 0.7993602 , -0.63078332, -0.67711584, ..., -0.06619302,
#         -0.09419673, -0.14039189]])

# %%
from imblearn.over_sampling import SMOTE
oversample=SMOTE()
x,y=oversample.fit_resample(x,y)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
dcn=tree.DecisionTreeClassifier()
dcn.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dcn.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8402489626556017

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[308,  44],
#        [ 33,  97]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target=['P','N']
print(classification_report(y_test,y_pred,target_names=target))
# Out:
#               precision    recall  f1-score   support
#
#            P       0.90      0.88      0.89       352
#            N       0.69      0.75      0.72       130
#
#     accuracy                           0.84       482
#    macro avg       0.80      0.81      0.80       482
# weighted avg       0.85      0.84      0.84       482

# %%
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
prob=dcn.predict_proba(x_test)
prob=prob[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,prob)

plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test,prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.metrics import (precision_recall_curve,PrecisionRecallDisplay)
precision, recall, _ = precision_recall_curve(y_test, prob)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.8112033195020747

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[333,  19],
#        [ 72,  58]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target=['P','N']
print(classification_report(y_test,y_pred,target_names=target))
# Out:
#               precision    recall  f1-score   support
#
#            P       0.82      0.95      0.88       352
#            N       0.75      0.45      0.56       130
#
#     accuracy                           0.81       482
#    macro avg       0.79      0.70      0.72       482
# weighted avg       0.80      0.81      0.79       482

# %%
prob=knn.predict_proba(x_test)
prob=prob[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,prob)

plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test,prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, prob)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svc=SVC(kernel="linear",random_state=0)
svc.probability = True
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=0)

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8112033195020747

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[327,  25],
#        [ 66,  64]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target=['P','N']
print(classification_report(y_test,y_pred,target_names=target))
# Out:
#               precision    recall  f1-score   support
#
#            P       0.83      0.93      0.88       352
#            N       0.72      0.49      0.58       130
#
#     accuracy                           0.81       482
#    macro avg       0.78      0.71      0.73       482
# weighted avg       0.80      0.81      0.80       482

# %%
prob=svc.predict_proba(x_test)
prob=prob[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,prob)

plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test,prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, prob)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8029045643153527

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[322,  30],
#        [ 65,  65]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target=['P','N']
print(classification_report(y_test,y_pred,target_names=target))
# Out:
#               precision    recall  f1-score   support
#
#            P       0.83      0.91      0.87       352
#            N       0.68      0.50      0.58       130
#
#     accuracy                           0.80       482
#    macro avg       0.76      0.71      0.72       482
# weighted avg       0.79      0.80      0.79       482

# %%
prob=lr.predict_proba(x_test)
prob=prob[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,prob)

plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test,prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, prob)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8755186721991701

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[334,  18],
#        [ 42,  88]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target=['P','N']
print(classification_report(y_test,y_pred,target_names=target))
# Out:
#               precision    recall  f1-score   support
#
#            P       0.89      0.95      0.92       352
#            N       0.83      0.68      0.75       130
#
#     accuracy                           0.88       482
#    macro avg       0.86      0.81      0.83       482
# weighted avg       0.87      0.88      0.87       482

# %%
prob=rf.predict_proba(x_test)
prob=prob[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,prob)

plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test,prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, prob)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %% [markdown]
# # NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.7800829875518672

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[293,  59],
#        [ 47,  83]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target=['P','N']
print(classification_report(y_test,y_pred,target_names=target))
# Out:
#               precision    recall  f1-score   support
#
#            P       0.86      0.83      0.85       352
#            N       0.58      0.64      0.61       130
#
#     accuracy                           0.78       482
#    macro avg       0.72      0.74      0.73       482
# weighted avg       0.79      0.78      0.78       482

# %%
prob=gnb.predict_proba(x_test)
prob=prob[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,prob)

plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test,prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, prob)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %% [markdown]
# # XGB

# %%
# !pip install xgboost
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(x_train,y_train)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\ashish\appdata\roaming\python\python39\site-packages (1.7.4)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred=model.predict(x_test)
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8879668049792531

# %%
from sklearn.datasets import make_classification
def new_dataset():
  X, Y = make_classification(n_samples=1925, n_features=32, n_informative=32,n_redundant=0,random_state=1)
  return X,Y

# %%
def new_models():
  models = dict()
  models['lr'] = LogisticRegression()
  models['knn'] = KNeighborsClassifier()
  models['dcn'] = tree.DecisionTreeClassifier()
  models['svc'] = SVC()
  models['gnb'] = GaussianNB()
  models['rf']=RandomForestClassifier()
  models['stacking'] = new_stacking()
  return models

# %%
from sklearn.ensemble import StackingClassifier
def new_stacking():
  level0 = list()
  level0.append(('lr', LogisticRegression()))
  level0.append(('knn', KNeighborsClassifier()))
  level0.append(('dcn', tree.DecisionTreeClassifier()))
  level0.append(('svm', SVC()))
  level0.append(('gnb', GaussianNB()))
  level0.append(('rf',RandomForestClassifier() ))
  level1 = LogisticRegression()
  model = StackingClassifier(estimators=level0, final_estimator=level1, cv=6)
  return model

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
def eval_model(model):
  cv = RepeatedStratifiedKFold(n_splits=20, n_repeats=4, random_state=2)
  scr = cross_val_score(model, X, Y, scoring='accuracy', cv=cv, n_jobs=-2, error_score='raise')
  return scr

# %%
from numpy import mean
from sklearn.model_selection import cross_val_score
from numpy import std
X,Y = new_dataset()
models = new_models()
results, names = list(), list()
for name, model in models.items():
  scr = eval_model(model)
  results.append(scr)
  names.append(name)
  print('>%s %.4f (%.4f)' % (name, mean(scr), std(scr)))
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# >lr 0.8239 (0.0330)
# >knn 0.9517 (0.0184)
# >dcn 0.7374 (0.0421)
# >svc 0.9666 (0.0174)
# >gnb 0.8097 (0.0398)
# >rf 0.8949 (0.0288)
# >stacking 0.9751 (0.0165)
